# %% [markdown]
# # Understanding student surveys
#
# Hello everyone! This is my first Jupyter notebook, I hope it's a good one.
#
# ## Abstract
#
# In this notebook we are going to explore some datas. Specificially the data that you provided me when we started the course. Little did you know when I had you fill out a survey for our class I was in fact, extracting data from your brain 🧠!
#
# ### A note on privacy
# The data extracted from the survey (a.k.a. typed up by me) was aggregated anonmyously and there are no identifiers to who was the orginal author of the answers provided. If answers provided revealing, de-anonomyzing details I redacted it.
#
# If even with that stipulation you don't feel comfortable with the fact that I shared this information please reach out to me. This excercise is meant to be fun but I understand that you did not know that your answers would be used in such a manner.
#
# ## Setup and Imports
#
# In order to run this notebook live you will need to make sure the following modules are installed on your machine:
#
# * wordcloud
# * matplotlib
# * pandas
# * numpy
#
# You can do this by running `pip install <module_name>` from your terminal/command prompts.

# %%
# importing all necessery modules 
from wordcloud import WordCloud, STOPWORDS 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

# %% [markdown]
# In addition to importing these modules you will also need to download the data file. `survey_data.csv`.

# %%
df = pd.read_csv(r"survey_data.csv", encoding ="latin-1")

# %% [markdown]
# ## Questions 2-4 Histograms
#
# For questions 2 - 4 you were asked to rate your abilities on a scale of 1-5. The code below uses the python library matplotlib to visualize these answers via a histogram.
#
# For question 2: You were asked to rate your comfort level with python on a scale of 0 - 5. (0=no experience, 5=daily use in a workplace)

# %%
num_bins = 6
x = df.Q2
n, bins, patches = plt.hist(x, num_bins, facecolor='red', alpha=0.5)
plt.show()

# %% [markdown]
# In Question 3 you were asked the same but with respect to discrete math.

# %%
x = df.Q3
n, bins, patches = plt.hist(x, num_bins, facecolor='blue', alpha=0.5)
plt.show()

# %% [markdown]
# In Question 4 you were asked to rate yourself on your familiarity with Probability and Statistics

# %%
x = df.Q3
n, bins, patches = plt.hist(x, num_bins, facecolor='green', alpha=0.5)
plt.show()

# %% [markdown]
# What I ascertain from these graphs is that, in general, you guys like to code way more than you like to do math! Personally, I'd have to agree but in AI you get a balance of both which is cool.

# %% [markdown]
# ## Open Answer Word Clouds
#
# For Questions 5 - 8 you all were asked open-ended questions about your interests in this course/AI/Computer Science in general. Here's a word cloud created of questions 5-8 combined.

# %%
words = ''
stopwords = set(STOPWORDS) 
stopwords.add('want')

  
# Aggregate all words from the dataset and place into an array
for val in (df.Q5 + df.Q6 + df.Q7 + df.Q8): 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
          
    for token in tokens: 
        words = words + token + ' '
  
  
wordcloud = WordCloud(width = 1200, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %% [markdown]
# ![AI Meme](./ai_doge.jpg)

# %% [markdown]
# ## Conclusions
#
# From what it looks like you all are really interested in AI and machine learning. Sounds like you're taking the right course! I hope this quick notebook shows how you can use some quick python to gather insights from a real, relevant, dataset. This is a test to see if Colab's dark magic works.
